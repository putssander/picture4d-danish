# %%
# !pip install ffmpeg
# Out:
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   DEPRECATION: Building 'ffmpeg' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'ffmpeg'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6127 sha256=050e0376fc7001a77d0e226bc8381df9af4b2fbbad14e255ee06a090908b3d14
#   Stored in directory: /home/ucloud/.cache/pip/wheels/26/21/0c/c26e09dff860a9071683e279445262346e008a9a1d2142c4ad
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import subprocess

# Directory containing your .m4a files
input_dir = "/work/speech/JANCD/"  # change this if needed
output_dir = input_dir + "wav/"  # output directory for converted files

os.makedirs(output_dir, exist_ok=True)

# Loop over all .m4a files in the directory
for filename in os.listdir(input_dir):
    if filename.lower().endswith(".m4a"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, os.path.splitext(filename)[0] + ".wav")

        # ffmpeg command: convert to mono, 16kHz WAV (common for speech models)
        command = [
            "ffmpeg",
            "-y",  # overwrite existing
            "-i", input_path,
            "-ac", "1",          # mono
            "-ar", "16000",      # 16 kHz
            output_path
        ]

        print(f"Converting: {filename} → {output_path}")
        subprocess.run(command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

print("✅ Conversion complete!")
# Out:
# Converting: Interview Per om chatbot brugt i HR.m4a → /work/speech/JANCD/wav/Interview Per om chatbot brugt i HR.wav
# Converting: Interview Anne om laering _ mette er med.m4a → /work/speech/JANCD/wav/Interview Anne om laering _ mette er med.wav
# Converting: Interview nr 2 med Helle fra H’alt om chatbot i vindindustri.m4a → /work/speech/JANCD/wav/Interview nr 2 med Helle fra H’alt om chatbot i vindindustri.wav
# Converting: Interview Karina om onboarding.m4a → /work/speech/JANCD/wav/Interview Karina om onboarding.wav
# ✅ Conversion complete!
